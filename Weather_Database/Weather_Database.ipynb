# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import API key
from config import g_key
# gmaps 
import gmaps
# Import the time module.
import time

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key = g_key)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
               
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
      
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 1 | palu
# Processing Record 7 of Set 1 | port moresby
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | phan thiet
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | ulladulla
# Processing Record 14 of Set 1 | narsaq
# Processing Record 15 of Set 1 | san policarpo
# Processing Record 16 of Set 1 | mount gambier
# Processing Record 17 of Set 1 | bandarbeyla
# Processing Record 18 of Set 1 | omboue
# Processing Record 19 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 1 | yulara
# Processing Record 21 of Set 1 | hauterive
# Processing Record 22 of Set 1 | dakar
# Processing Record 23 of Set 1 | fenoarivo
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | gudiyattam
# City not found. Skipping...
# Processing Record 26 of Set 1 | trelew
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | sao miguel do araguaia
# Processing Record 29 of Set 1 | sao joao da barra
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | saint george
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | usevya
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | los llanos de aridane
# Processing Record 36 of Set 1 | bara
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | visnes
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | vestmannaeyjar
# Processing Record 44 of Set 1 | dothan
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | margate
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | neuquen
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | gerede
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | ambon
# Processing Record 4 of Set 2 | provideniya
# Processing Record 5 of Set 2 | san quintin
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | santa cruz
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | odweyne
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | khash
# Processing Record 12 of Set 2 | luderitz
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | buala
# Processing Record 15 of Set 2 | richards bay
# Processing Record 16 of Set 2 | sakakah
# Processing Record 17 of Set 2 | tobermory
# Processing Record 18 of Set 2 | neryungri
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | oranjestad
# Processing Record 21 of Set 2 | dymer
# Processing Record 22 of Set 2 | medicine hat
# Processing Record 23 of Set 2 | peniche
# Processing Record 24 of Set 2 | vacaria
# Processing Record 25 of Set 2 | tomatlan
# Processing Record 26 of Set 2 | tamale
# Processing Record 27 of Set 2 | bashtanka
# Processing Record 28 of Set 2 | hualmay
# Processing Record 29 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 2 | andenes
# Processing Record 31 of Set 2 | svilengrad
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | nendaz
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | saint anthony
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | honghu
# Processing Record 41 of Set 2 | dawlatabad
# Processing Record 42 of Set 2 | fort saint james
# Processing Record 43 of Set 2 | lingao
# Processing Record 44 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | vadso
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | dubenskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | vallenar
# Processing Record 1 of Set 3 | scarborough
# Processing Record 2 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 3 | kahului
# Processing Record 4 of Set 3 | lumphat
# Processing Record 5 of Set 3 | shorewood
# Processing Record 6 of Set 3 | coracora
# Processing Record 7 of Set 3 | nizhniy kuranakh
# Processing Record 8 of Set 3 | morro bay
# Processing Record 9 of Set 3 | kloulklubed
# Processing Record 10 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 3 | vila velha
# Processing Record 12 of Set 3 | ostrovnoy
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | senneterre
# Processing Record 15 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 16 of Set 3 | pangnirtung
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | sorland
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | westport
# Processing Record 21 of Set 3 | rundu
# Processing Record 22 of Set 3 | kavieng
# Processing Record 23 of Set 3 | portree
# Processing Record 24 of Set 3 | ibotirama
# Processing Record 25 of Set 3 | whitley bay
# Processing Record 26 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 3 | iracoubo
# Processing Record 28 of Set 3 | luwuk
# Processing Record 29 of Set 3 | hobyo
# Processing Record 30 of Set 3 | nicoya
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | cabo san lucas
# Processing Record 33 of Set 3 | lata
# Processing Record 34 of Set 3 | sao miguel do iguacu
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | bucerias
# Processing Record 37 of Set 3 | maumere
# Processing Record 38 of Set 3 | ola
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | yumen
# Processing Record 41 of Set 3 | larsnes
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | pacific grove
# Processing Record 44 of Set 3 | tessalit
# Processing Record 45 of Set 3 | longyearbyen
# Processing Record 46 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 3 | meulaboh
# Processing Record 48 of Set 3 | saucillo
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | faya
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | byron bay
# Processing Record 3 of Set 4 | lujan
# Processing Record 4 of Set 4 | dandong
# Processing Record 5 of Set 4 | saint-augustin
# Processing Record 6 of Set 4 | tarko-sale
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | prince rupert
# Processing Record 11 of Set 4 | mount isa
# Processing Record 12 of Set 4 | vaini
# Processing Record 13 of Set 4 | platteville
# Processing Record 14 of Set 4 | alofi
# Processing Record 15 of Set 4 | goderich
# Processing Record 16 of Set 4 | saint-georges
# Processing Record 17 of Set 4 | floro
# Processing Record 18 of Set 4 | bredasdorp
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | miyoshi
# Processing Record 21 of Set 4 | chardara
# Processing Record 22 of Set 4 | klaksvik
# Processing Record 23 of Set 4 | bagado
# Processing Record 24 of Set 4 | peterhead
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | diu
# Processing Record 27 of Set 4 | margosatubig
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 4 | abha
# Processing Record 31 of Set 4 | lerwick
# Processing Record 32 of Set 4 | humberto de campos
# Processing Record 33 of Set 4 | portland
# Processing Record 34 of Set 4 | lagoa
# Processing Record 35 of Set 4 | mitsamiouli
# Processing Record 36 of Set 4 | bambanglipuro
# Processing Record 37 of Set 4 | san cristobal
# Processing Record 38 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 4 | cloquet
# Processing Record 40 of Set 4 | mackay
# Processing Record 41 of Set 4 | khandbari
# Processing Record 42 of Set 4 | grand gaube
# Processing Record 43 of Set 4 | kyzyl-suu
# Processing Record 44 of Set 4 | xining
# Processing Record 45 of Set 4 | beidao
# Processing Record 46 of Set 4 | esperance
# Processing Record 47 of Set 4 | noumea
# Processing Record 48 of Set 4 | hondo
# Processing Record 49 of Set 4 | honiara
# Processing Record 50 of Set 4 | faanui
# Processing Record 1 of Set 5 | kanashevo
# Processing Record 2 of Set 5 | cayenne
# Processing Record 3 of Set 5 | ayr
# Processing Record 4 of Set 5 | himora
# City not found. Skipping...
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | codrington
# Processing Record 7 of Set 5 | russell
# Processing Record 8 of Set 5 | waddan
# Processing Record 9 of Set 5 | bhatkal
# Processing Record 10 of Set 5 | magadan
# Processing Record 11 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 12 of Set 5 | isangel
# Processing Record 13 of Set 5 | brigantine
# Processing Record 14 of Set 5 | skjervoy
# Processing Record 15 of Set 5 | hamilton
# Processing Record 16 of Set 5 | muros
# Processing Record 17 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 5 | sembakung
# Processing Record 21 of Set 5 | praia da vitoria
# Processing Record 22 of Set 5 | nome
# Processing Record 23 of Set 5 | cienfuegos
# Processing Record 24 of Set 5 | port hardy
# Processing Record 25 of Set 5 | effium
# Processing Record 26 of Set 5 | joshimath
# Processing Record 27 of Set 5 | gandajika
# Processing Record 28 of Set 5 | vrangel
# Processing Record 29 of Set 5 | tiarei
# Processing Record 30 of Set 5 | te anau
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | lumberton
# Processing Record 33 of Set 5 | kamuli
# Processing Record 34 of Set 5 | lorengau
# Processing Record 35 of Set 5 | rheinfelden
# Processing Record 36 of Set 5 | pyu
# Processing Record 37 of Set 5 | kodiak
# Processing Record 38 of Set 5 | wuan
# Processing Record 39 of Set 5 | cap malheureux
# Processing Record 40 of Set 5 | havre-saint-pierre
# Processing Record 41 of Set 5 | lavrentiya
# Processing Record 42 of Set 5 | zonguldak
# Processing Record 43 of Set 5 | nueva concepcion
# Processing Record 44 of Set 5 | tura
# Processing Record 45 of Set 5 | atuona
# Processing Record 46 of Set 5 | slave lake
# Processing Record 47 of Set 5 | zhitikara
# City not found. Skipping...
# Processing Record 48 of Set 5 | port-cartier
# Processing Record 49 of Set 5 | batagay-alyta
# Processing Record 50 of Set 5 | sobolevo
# Processing Record 1 of Set 6 | azul
# Processing Record 2 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 6 | sur
# Processing Record 4 of Set 6 | merauke
# Processing Record 5 of Set 6 | taldan
# Processing Record 6 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 6 | pampa
# Processing Record 8 of Set 6 | grindavik
# Processing Record 9 of Set 6 | axim
# Processing Record 10 of Set 6 | beyneu
# Processing Record 11 of Set 6 | itarema
# Processing Record 12 of Set 6 | sioux lookout
# Processing Record 13 of Set 6 | iquique
# Processing Record 14 of Set 6 | brive-la-gaillarde
# Processing Record 15 of Set 6 | hukuntsi
# Processing Record 16 of Set 6 | sao felix do xingu
# Processing Record 17 of Set 6 | paso de carrasco
# Processing Record 18 of Set 6 | aklavik
# Processing Record 19 of Set 6 | thompson
# Processing Record 20 of Set 6 | tiksi
# Processing Record 21 of Set 6 | kendal
# Processing Record 22 of Set 6 | korla
# Processing Record 23 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | general artigas
# Processing Record 25 of Set 6 | barahona
# Processing Record 26 of Set 6 | oriximina
# Processing Record 27 of Set 6 | bathsheba
# Processing Record 28 of Set 6 | chom bung
# City not found. Skipping...
# Processing Record 29 of Set 6 | ballina
# Processing Record 30 of Set 6 | beloha
# Processing Record 31 of Set 6 | sterling
# Processing Record 32 of Set 6 | nenjiang
# Processing Record 33 of Set 6 | east london
# Processing Record 34 of Set 6 | zacualpan
# Processing Record 35 of Set 6 | kaliua
# Processing Record 36 of Set 6 | mizdah
# Processing Record 37 of Set 6 | mar del plata
# Processing Record 38 of Set 6 | ariquemes
# Processing Record 39 of Set 6 | boyolangu
# Processing Record 40 of Set 6 | solhan
# Processing Record 41 of Set 6 | husavik
# Processing Record 42 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 6 | nizhniy baskunchak
# Processing Record 44 of Set 6 | tuatapere
# Processing Record 45 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 46 of Set 6 | norman wells
# Processing Record 47 of Set 6 | piotrkow trybunalski
# Processing Record 48 of Set 6 | aksay
# Processing Record 49 of Set 6 | sept-iles
# Processing Record 50 of Set 6 | pitimbu
# Processing Record 1 of Set 7 | tateyama
# Processing Record 2 of Set 7 | mana
# Processing Record 3 of Set 7 | nuuk
# Processing Record 4 of Set 7 | beterou
# Processing Record 5 of Set 7 | los zacatones
# Processing Record 6 of Set 7 | mecca
# Processing Record 7 of Set 7 | dauriya
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | namibe
# Processing Record 10 of Set 7 | orange
# Processing Record 11 of Set 7 | dingle
# Processing Record 12 of Set 7 | boddam
# Processing Record 13 of Set 7 | lompoc
# Processing Record 14 of Set 7 | haines junction
# Processing Record 15 of Set 7 | ichtegem
# Processing Record 16 of Set 7 | digri
# Processing Record 17 of Set 7 | kropotkin
# Processing Record 18 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 7 | fitjar
# Processing Record 20 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 7 | vardo
# Processing Record 22 of Set 7 | soanierana ivongo
# Processing Record 23 of Set 7 | ilulissat
# Processing Record 24 of Set 7 | verkhnevilyuysk
# Processing Record 25 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 7 | sri aman
# Processing Record 27 of Set 7 | berlevag
# Processing Record 28 of Set 7 | lebu
# Processing Record 29 of Set 7 | novaya bryan
# Processing Record 30 of Set 7 | okhotsk
# Processing Record 31 of Set 7 | srednekolymsk
# Processing Record 32 of Set 7 | santa vitoria do palmar
# Processing Record 33 of Set 7 | clyde river
# Processing Record 34 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 7 | zhigansk
# Processing Record 36 of Set 7 | airai
# Processing Record 37 of Set 7 | victoria
# Processing Record 38 of Set 7 | santa cecilia
# Processing Record 39 of Set 7 | baykit
# Processing Record 40 of Set 7 | brae
# Processing Record 41 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 7 | teya
# Processing Record 43 of Set 7 | toora-khem
# Processing Record 44 of Set 7 | nanortalik
# Processing Record 45 of Set 7 | vaitape
# Processing Record 46 of Set 7 | yinchuan
# Processing Record 47 of Set 7 | lewistown
# Processing Record 48 of Set 7 | ridge
# Processing Record 49 of Set 7 | beringovskiy
# Processing Record 50 of Set 7 | vicuna
# Processing Record 1 of Set 8 | acarau
# Processing Record 2 of Set 8 | marsh harbour
# Processing Record 3 of Set 8 | menongue
# Processing Record 4 of Set 8 | zeya
# Processing Record 5 of Set 8 | akyab
# Processing Record 6 of Set 8 | hami
# Processing Record 7 of Set 8 | ozark
# Processing Record 8 of Set 8 | bartica
# Processing Record 9 of Set 8 | chuy
# Processing Record 10 of Set 8 | tautira
# Processing Record 11 of Set 8 | tsiroanomandidy
# Processing Record 12 of Set 8 | jining
# Processing Record 13 of Set 8 | awjilah
# Processing Record 14 of Set 8 | formosa
# Processing Record 15 of Set 8 | karratha
# Processing Record 16 of Set 8 | filiates
# Processing Record 17 of Set 8 | tucumcari
# Processing Record 18 of Set 8 | sabzevar
# Processing Record 19 of Set 8 | bilma
# Processing Record 20 of Set 8 | hakkari
# Processing Record 21 of Set 8 | huarmey
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | sinnamary
# Processing Record 24 of Set 8 | taizhou
# Processing Record 25 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 8 | severo-kurilsk
# Processing Record 27 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 8 | kajaani
# Processing Record 29 of Set 8 | yar-sale
# Processing Record 30 of Set 8 | portales
# Processing Record 31 of Set 8 | vanimo
# Processing Record 32 of Set 8 | manyana
# Processing Record 33 of Set 8 | road town
# Processing Record 34 of Set 8 | cidreira
# Processing Record 35 of Set 8 | pinotepa nacional
# Processing Record 36 of Set 8 | samarinda
# Processing Record 37 of Set 8 | helong
# Processing Record 38 of Set 8 | darnah
# Processing Record 39 of Set 8 | agva
# City not found. Skipping...
# Processing Record 40 of Set 8 | mankono
# Processing Record 41 of Set 8 | cukai
# Processing Record 42 of Set 8 | semey
# Processing Record 43 of Set 8 | bambous virieux
# Processing Record 44 of Set 8 | beckley
# Processing Record 45 of Set 8 | mizpe ramon
# City not found. Skipping...
# Processing Record 46 of Set 8 | college
# Processing Record 47 of Set 8 | claresholm
# Processing Record 48 of Set 8 | langsa
# Processing Record 49 of Set 8 | pekan
# Processing Record 50 of Set 8 | polunochnoye
# Processing Record 1 of Set 9 | kemijarvi
# Processing Record 2 of Set 9 | deputatskiy
# Processing Record 3 of Set 9 | bolobo
# Processing Record 4 of Set 9 | manakara
# Processing Record 5 of Set 9 | vilhena
# Processing Record 6 of Set 9 | belyy yar
# Processing Record 7 of Set 9 | waipawa
# Processing Record 8 of Set 9 | ishigaki
# Processing Record 9 of Set 9 | celestun
# Processing Record 10 of Set 9 | almeirim
# Processing Record 11 of Set 9 | marquette
# Processing Record 12 of Set 9 | quatre cocos
# Processing Record 13 of Set 9 | garden city
# Processing Record 14 of Set 9 | katsuura
# Processing Record 15 of Set 9 | bonfim
# Processing Record 16 of Set 9 | campos
# Processing Record 17 of Set 9 | nouadhibou
# Processing Record 18 of Set 9 | olafsvik
# Processing Record 19 of Set 9 | high level
# Processing Record 20 of Set 9 | nikolskoye
# Processing Record 21 of Set 9 | madiun
# Processing Record 22 of Set 9 | roma
# Processing Record 23 of Set 9 | shenjiamen
# Processing Record 24 of Set 9 | ornskoldsvik
# Processing Record 25 of Set 9 | padang
# Processing Record 26 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 9 | san joaquin
# Processing Record 28 of Set 9 | maxixe
# Processing Record 29 of Set 9 | lac du bonnet
# Processing Record 30 of Set 9 | comarapa
# Processing Record 31 of Set 9 | kaitangata
# Processing Record 32 of Set 9 | edson
# Processing Record 33 of Set 9 | seoul
# Processing Record 34 of Set 9 | port elizabeth
# Processing Record 35 of Set 9 | jingcheng
# Processing Record 36 of Set 9 | akoupe
# Processing Record 37 of Set 9 | lensk
# Processing Record 38 of Set 9 | vao
# Processing Record 39 of Set 9 | hirara
# Processing Record 40 of Set 9 | eyl
# Processing Record 41 of Set 9 | port lincoln
# Processing Record 42 of Set 9 | coaticook
# Processing Record 43 of Set 9 | hasaki
# Processing Record 44 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 45 of Set 9 | juneau
# Processing Record 46 of Set 9 | calarca
# Processing Record 47 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 9 | lasa
# Processing Record 50 of Set 9 | mangan
# Processing Record 1 of Set 10 | hambantota
# Processing Record 2 of Set 10 | djenne
# Processing Record 3 of Set 10 | manavgat
# Processing Record 4 of Set 10 | bismarck
# Processing Record 5 of Set 10 | kushiro
# Processing Record 6 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 7 of Set 10 | graaff-reinet
# Processing Record 8 of Set 10 | sumoto
# Processing Record 9 of Set 10 | makinsk
# Processing Record 10 of Set 10 | salaga
# Processing Record 11 of Set 10 | arys
# Processing Record 12 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 10 | fare
# Processing Record 14 of Set 10 | ngunguru
# Processing Record 15 of Set 10 | fatehabad
# Processing Record 16 of Set 10 | andros
# Processing Record 17 of Set 10 | aojiang
# Processing Record 18 of Set 10 | masindi
# Processing Record 19 of Set 10 | conceicao da barra
# Processing Record 20 of Set 10 | xai-xai
# Processing Record 21 of Set 10 | atasu
# Processing Record 22 of Set 10 | kyra
# Processing Record 23 of Set 10 | paita
# Processing Record 24 of Set 10 | kommunisticheskiy
# Processing Record 25 of Set 10 | salinopolis
# Processing Record 26 of Set 10 | viedma
# Processing Record 27 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 10 | iskilip
# Processing Record 29 of Set 10 | mangai
# Processing Record 30 of Set 10 | adrar
# Processing Record 31 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 32 of Set 10 | manggar
# Processing Record 33 of Set 10 | wanning
# Processing Record 34 of Set 10 | fort nelson
# Processing Record 35 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 10 | baghdad
# Processing Record 37 of Set 10 | diamantino
# Processing Record 38 of Set 10 | batagay
# Processing Record 39 of Set 10 | qasigiannguit
# Processing Record 40 of Set 10 | sulangan
# Processing Record 41 of Set 10 | martapura
# Processing Record 42 of Set 10 | araguatins
# City not found. Skipping...
# Processing Record 43 of Set 10 | shingu
# Processing Record 44 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 45 of Set 10 | namatanai
# Processing Record 46 of Set 10 | emerald
# Processing Record 47 of Set 10 | socorro
# Processing Record 48 of Set 10 | saurimo
# Processing Record 49 of Set 10 | fernie
# Processing Record 50 of Set 10 | inhambane
# Processing Record 1 of Set 11 | jonuta
# Processing Record 2 of Set 11 | abnub
# Processing Record 3 of Set 11 | tandag
# Processing Record 4 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 5 of Set 11 | sahuaripa
# Processing Record 6 of Set 11 | winston-salem
# Processing Record 7 of Set 11 | seryshevo
# Processing Record 8 of Set 11 | goundam
# Processing Record 9 of Set 11 | albion
# Processing Record 10 of Set 11 | pisco
# Processing Record 11 of Set 11 | izhma
# Processing Record 12 of Set 11 | george town
# Processing Record 13 of Set 11 | tual
# Processing Record 14 of Set 11 | guerrero negro
# Processing Record 15 of Set 11 | ambam
# Processing Record 16 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 11 | ambilobe
# Processing Record 19 of Set 11 | great falls
# Processing Record 20 of Set 11 | jumla
# Processing Record 21 of Set 11 | muncar
# Processing Record 22 of Set 11 | chicama
# Processing Record 23 of Set 11 | kapiri mposhi
# Processing Record 24 of Set 11 | ribas do rio pardo
# Processing Record 25 of Set 11 | cherskiy
# Processing Record 26 of Set 11 | ahipara
# Processing Record 27 of Set 11 | robertsport
# Processing Record 28 of Set 11 | olinda
# Processing Record 29 of Set 11 | kralendijk
# Processing Record 30 of Set 11 | the pas
# Processing Record 31 of Set 11 | lufilufi
# Processing Record 32 of Set 11 | paamiut
# Processing Record 33 of Set 11 | ixtapa
# Processing Record 34 of Set 11 | mao
# Processing Record 35 of Set 11 | borovikha
# Processing Record 36 of Set 11 | alta floresta
# Processing Record 37 of Set 11 | coahuayana
# Processing Record 38 of Set 11 | wailuku
# Processing Record 39 of Set 11 | salinas
# Processing Record 40 of Set 11 | bonthe
# Processing Record 41 of Set 11 | imperia
# Processing Record 42 of Set 11 | arandas
# Processing Record 43 of Set 11 | nantucket
# Processing Record 44 of Set 11 | ponta delgada
# Processing Record 45 of Set 11 | rocha
# Processing Record 46 of Set 11 | port blair
# Processing Record 47 of Set 11 | makakilo city
# Processing Record 48 of Set 11 | namuac
# Processing Record 49 of Set 11 | umm lajj
# Processing Record 50 of Set 11 | raudeberg
# Processing Record 1 of Set 12 | quepos
# Processing Record 2 of Set 12 | leningradskiy
# Processing Record 3 of Set 12 | along
# Processing Record 4 of Set 12 | xinmin
# Processing Record 5 of Set 12 | ahuimanu
# Processing Record 6 of Set 12 | lokosovo
# Processing Record 7 of Set 12 | kudahuvadhoo
# Processing Record 8 of Set 12 | kununurra
# Processing Record 9 of Set 12 | batsfjord
# Processing Record 10 of Set 12 | praia
# Processing Record 11 of Set 12 | goundi
# Processing Record 12 of Set 12 | kutum
# Processing Record 13 of Set 12 | corpus christi
# Processing Record 14 of Set 12 | trairi
# Processing Record 15 of Set 12 | talnakh
# Processing Record 16 of Set 12 | kuala terengganu
# Processing Record 17 of Set 12 | kruisfontein
# Processing Record 18 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 12 | imeni poliny osipenko
# Processing Record 20 of Set 12 | moose factory
# Processing Record 21 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 22 of Set 12 | atikokan
# Processing Record 23 of Set 12 | porbandar
# Processing Record 24 of Set 12 | pelym
# Processing Record 25 of Set 12 | pemba
# Processing Record 26 of Set 12 | kirakira
# Processing Record 27 of Set 12 | kitimat
# Processing Record 28 of Set 12 | mehamn
# Processing Record 29 of Set 12 | ossora
# Processing Record 30 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 12 | coruripe
# Processing Record 32 of Set 12 | dombarovskiy
# Processing Record 33 of Set 12 | barabai
# Processing Record 34 of Set 12 | dwarka
# Processing Record 35 of Set 12 | solms
# Processing Record 36 of Set 12 | leshukonskoye
# Processing Record 37 of Set 12 | trapani
# Processing Record 38 of Set 12 | yarada
# Processing Record 39 of Set 12 | fairbanks
# Processing Record 40 of Set 12 | inuvik
# Processing Record 41 of Set 12 | kieta
# Processing Record 42 of Set 12 | muyezerskiy
# Processing Record 43 of Set 12 | wellington
# Processing Record 44 of Set 12 | jimo
# Processing Record 45 of Set 12 | roebourne
# Processing Record 46 of Set 12 | tagab
# Processing Record 47 of Set 12 | uige
# Processing Record 48 of Set 12 | nambucca heads
# Processing Record 49 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 12 | sinjai
# Processing Record 1 of Set 13 | nalut
# Processing Record 2 of Set 13 | alice springs
# Processing Record 3 of Set 13 | seka
# Processing Record 4 of Set 13 | louga
# Processing Record 5 of Set 13 | cruzeiro do sul
# Processing Record 6 of Set 13 | leh
# Processing Record 7 of Set 13 | amfissa
# Processing Record 8 of Set 13 | la asuncion
# Processing Record 9 of Set 13 | samarai
# Processing Record 10 of Set 13 | cockburn town
# Processing Record 11 of Set 13 | mogok
# Processing Record 12 of Set 13 | half moon bay
# Processing Record 13 of Set 13 | quang ngai
# Processing Record 14 of Set 13 | uarini
# Processing Record 15 of Set 13 | kollumerland
# City not found. Skipping...
# Processing Record 16 of Set 13 | upernavik
# Processing Record 17 of Set 13 | ivanava
# Processing Record 18 of Set 13 | stykkisholmur
# Processing Record 19 of Set 13 | lincoln
# Processing Record 20 of Set 13 | harper
# Processing Record 21 of Set 13 | camacha
# Processing Record 22 of Set 13 | labuhan
# Processing Record 23 of Set 13 | champerico
# Processing Record 24 of Set 13 | pontianak
# Processing Record 25 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 13 | gorontalo
# Processing Record 27 of Set 13 | taoudenni
# Processing Record 28 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 29 of Set 13 | mwinilunga
# Processing Record 30 of Set 13 | wajir
# Processing Record 31 of Set 13 | saint-paul
# Processing Record 32 of Set 13 | sitka
# Processing Record 33 of Set 13 | mathathane
# Processing Record 34 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 13 | troyes
# Processing Record 36 of Set 13 | karasjok
# Processing Record 37 of Set 13 | ransang
# Processing Record 38 of Set 13 | rurrenabaque
# Processing Record 39 of Set 13 | oudtshoorn
# Processing Record 40 of Set 13 | angoche
# Processing Record 41 of Set 13 | pahrump
# Processing Record 42 of Set 13 | foumban
# Processing Record 43 of Set 13 | jucas
# Processing Record 44 of Set 13 | esna
# Processing Record 45 of Set 13 | porto velho
# Processing Record 46 of Set 13 | ulaangom
# Processing Record 47 of Set 13 | kuching
# Processing Record 48 of Set 13 | nyurba
# Processing Record 49 of Set 13 | sao borja
# Processing Record 50 of Set 13 | jacareacanga
# Processing Record 1 of Set 14 | mapiripan
# Processing Record 2 of Set 14 | okha
# Processing Record 3 of Set 14 | acapulco
# Processing Record 4 of Set 14 | sovetskiy
# Processing Record 5 of Set 14 | guilin
# Processing Record 6 of Set 14 | ishinomaki
# Processing Record 7 of Set 14 | victor harbor
# Processing Record 8 of Set 14 | guarapari
# Processing Record 9 of Set 14 | olga
# Processing Record 10 of Set 14 | ambulu
# Processing Record 11 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 14 | mlimba
# Processing Record 13 of Set 14 | plover
# Processing Record 14 of Set 14 | severo-yeniseyskiy
# Processing Record 15 of Set 14 | taggia
# Processing Record 16 of Set 14 | plouzane
# Processing Record 17 of Set 14 | takoradi
# Processing Record 18 of Set 14 | johi
# Processing Record 19 of Set 14 | burica
# City not found. Skipping...
# Processing Record 20 of Set 14 | kinkala
# Processing Record 21 of Set 14 | roald
# Processing Record 22 of Set 14 | krasne
# Processing Record 23 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 14 | zhanakorgan
# Processing Record 25 of Set 14 | bayanday
# Processing Record 26 of Set 14 | mahibadhoo
# Processing Record 27 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 14 | goksun
# Processing Record 30 of Set 14 | ancud
# Processing Record 31 of Set 14 | gat
# Processing Record 32 of Set 14 | sabang
# Processing Record 33 of Set 14 | zhangjiakou
# Processing Record 34 of Set 14 | raahe
# Processing Record 35 of Set 14 | nagato
# Processing Record 36 of Set 14 | maraba
# Processing Record 37 of Set 14 | vung tau
# Processing Record 38 of Set 14 | savinka
# Processing Record 39 of Set 14 | touros
# Processing Record 40 of Set 14 | chaozhou
# Processing Record 41 of Set 14 | tazovskiy
# Processing Record 42 of Set 14 | muisne
# Processing Record 43 of Set 14 | narok
# Processing Record 44 of Set 14 | blythe
# Processing Record 45 of Set 14 | pochutla
# Processing Record 46 of Set 14 | pemangkat
# Processing Record 47 of Set 14 | oyek
# Processing Record 48 of Set 14 | ligayan
# Processing Record 49 of Set 14 | morgan city
# Processing Record 50 of Set 14 | udachnyy
# Processing Record 1 of Set 15 | ghanzi
# Processing Record 2 of Set 15 | rawson
# Processing Record 3 of Set 15 | turbat
# Processing Record 4 of Set 15 | mayo
# Processing Record 5 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | chara
# Processing Record 7 of Set 15 | chester
# Processing Record 8 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 15 | mbeya
# Processing Record 10 of Set 15 | port hedland
# Processing Record 11 of Set 15 | sao gabriel da cachoeira
# Processing Record 12 of Set 15 | mount hagen
# Processing Record 13 of Set 15 | hovd
# Processing Record 14 of Set 15 | raton
# Processing Record 15 of Set 15 | felanitx
# Processing Record 16 of Set 15 | yarega
# Processing Record 17 of Set 15 | uralets
# Processing Record 18 of Set 15 | kosovo polje
# Processing Record 19 of Set 15 | yershichi
# Processing Record 20 of Set 15 | saint-pierre
# Processing Record 21 of Set 15 | fort wellington
# Processing Record 22 of Set 15 | billings
# Processing Record 23 of Set 15 | ushtobe
# Processing Record 24 of Set 15 | bien hoa
# Processing Record 25 of Set 15 | sotnikovo
# Processing Record 26 of Set 15 | jau
# Processing Record 27 of Set 15 | chake chake
# Processing Record 28 of Set 15 | kohlu
# Processing Record 29 of Set 15 | laguna
# Processing Record 30 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 15 | maniitsoq
# Processing Record 32 of Set 15 | ucluelet
# Processing Record 33 of Set 15 | sandwick
# Processing Record 34 of Set 15 | simao
# Processing Record 35 of Set 15 | iwanai
# Processing Record 36 of Set 15 | santa marta
# Processing Record 37 of Set 15 | chowchilla
# Processing Record 38 of Set 15 | keuruu
# Processing Record 39 of Set 15 | mapastepec
# Processing Record 40 of Set 15 | anadyr
# Processing Record 41 of Set 15 | sankarpur
# Processing Record 42 of Set 15 | murray
# Processing Record 43 of Set 15 | ewa beach
# Processing Record 44 of Set 15 | carver
# Processing Record 45 of Set 15 | fenoarivo atsinanana
# Processing Record 46 of Set 15 | joao pinheiro
# Processing Record 47 of Set 15 | kaa-khem
# Processing Record 48 of Set 15 | auki
# Processing Record 49 of Set 15 | shaoguan
# Processing Record 50 of Set 15 | hurricane
# Processing Record 1 of Set 16 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 16 | buraydah
# Processing Record 3 of Set 16 | litoral del san juan
# City not found. Skipping...
# Processing Record 4 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 5 of Set 16 | juifang
# City not found. Skipping...
# Processing Record 6 of Set 16 | kashi
# Processing Record 7 of Set 16 | inta
# Processing Record 8 of Set 16 | xacmaz
# Processing Record 9 of Set 16 | alyangula
# Processing Record 10 of Set 16 | usinsk
# Processing Record 11 of Set 16 | krasnoselkup
# Processing Record 12 of Set 16 | ayan
# Processing Record 13 of Set 16 | butterworth
# Processing Record 14 of Set 16 | shache
# Processing Record 15 of Set 16 | parrita
# Processing Record 16 of Set 16 | inirida
# Processing Record 17 of Set 16 | sakaiminato
# Processing Record 18 of Set 16 | maunabo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tasiilaq  65.6145  -37.6368      6.96        55           0
# 1      Hermanus -34.4187   19.2345     69.80        87           3
# 2  Punta Arenas -53.1500  -70.9167     55.11        62         100
# 3          Palu  -0.8917  119.8707     76.37        94         100
# 4  Port Moresby  -9.4431  147.1797     80.02        83          20
#
#    Wind Speed Country Current Description                 Date
# 0        4.85      GL           clear sky  2022-03-21 23:02:11
# 1       11.21      ZA           clear sky  2022-03-21 23:02:12
# 2       21.12      CL     overcast clouds  2022-03-21 23:00:14
# 3        2.55      ID     overcast clouds  2022-03-21 23:02:12
# 4        5.75      PG          few clouds  2022-03-21 22:52:23

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tasiilaq      GL  65.6145  -37.6368      6.96        55           0
# 1      Hermanus      ZA -34.4187   19.2345     69.80        87           3
# 2  Punta Arenas      CL -53.1500  -70.9167     55.11        62         100
# 3          Palu      ID  -0.8917  119.8707     76.37        94         100
# 4  Port Moresby      PG  -9.4431  147.1797     80.02        83          20
#
#    Wind Speed Current Description
# 0        4.85           clear sky
# 1       11.21           clear sky
# 2       21.12     overcast clouds
# 3        2.55     overcast clouds
# 4        5.75          few clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
